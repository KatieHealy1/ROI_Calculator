# %%
import time 
from time import sleep 
import math

class ROI():

    def __init__(self):
        self.mortgage = 0
        self.fees = {
            "taxes": 150,
            "insurance": 100,
            "water": 30,
            "garbage": 30,
            "sewer": 30,
            "lawn care": 500,
            "property management": 200,
        }
        self.income = {}
        self.units = 0
        self.cash_flow = 0

    def cost(self):
        home_cost = int(input("What is the cost of the home you are interested in purchasing ? "))
        down_payment = int(input("What percentage can you put down? "))
        result = (down_payment)/100
        self.mortgage += (result)*(home_cost)
        loan = (home_cost) - self.mortgage
        m = 12 # months in a year
        l = 30 # loan 
        r = 0.05 # interest rate
        mortgage = (loan)                 
        mortgage_calc = (1-(1+r/m)**(-m*l))/(r/m)
        monthly_payment = round(mortgage/mortgage_calc, 2)
        self.fees["mortgage"] = monthly_payment
        unit = int(input("How many units would you be able to rent out? "))
        self.units += int(unit)
        extra_cost = unit*100
        self.fees["capital expenditures"] = extra_cost
        self.fees["repairs"] = extra_cost
        rent = int(input("If you choose to rent out the space, how much would you charge a month in total? "))
        self.income["monthly rent for all units combines"] = rent
        result3 = float(rent)*0.05
        self.fees["vacancy"] = result3
        self.Income()

    def Income(self):
        sleep(1)
        print("\n")
        print("Great, now that you have an idea of how much you can charge for rent let's see some other ways you can make additional income.")

        alternative_income = input("What sources of alternative income will you have? Charge for laundry, offer storage unit, a parking space, all of the above, or nothing else? ")
        
        if alternative_income.lower() == "charge for laundry":
            print("This is a great way to add some extra income.")
            laundry = int(input("The average person does about 6 loads of laundry a month. How much would you like to charge for using a washer AND dryer? "))
            if alternative_income not in self.income.keys():
                self.income[alternative_income] = (laundry*6)* self.units 
                print(self.income)
                self.expenses()
                
        if alternative_income.lower() == "offer storage unit":
            storage = int(input("A storage unit conveniently located in the building can go for about $50-$100/month. How much would you like to charge for storage? "))
            if alternative_income not in self.income.keys():
                self.income[alternative_income] = storage
                self.expenses()
        
                
        if alternative_income.lower() == "a parking space":
            parking = int(input("How much would you like to charge for parking? If it is a covered spot you can charge a bit more. "))
            if alternative_income not in self.income.keys():
                self.income[alternative_income] = parking
                self.expenses()
                
        if alternative_income.lower() == "all of the above":
            laundry = int(input("The average person does about 6 loads of laundry a month. How much would you like to charge for using a washer AND dryer? "))
            self.income["laundry"] = (laundry*6)* self.units 
            storage = int(input("A storage unit conveniently located in the building can go for about $50-$100/month. How much would you like to charge for storage? "))
            self.income["storage"] = storage                
            parking = int(input("How much would you like to charge for parking? If it is a covered spot you can charge a bit more. "))
            self.income["parking"] = parking
            self.expenses()
            
        if alternative_income.lower() == "none":
            print("Looks like you are not a greedy landlord. Let's move on. ")
            self.expenses()


    def expenses(self):
        print("\n")
        sleep(1)
        print("Another thing you have to think about is all the additional expenses when purchasing property.")
        print("\n")
        print("*******")
        sleep(2)
        print("The tenent should be responsible for gas, electric, and internet but the rest are generally covered by the owner. For now I will add the rest to your total cost based on the average for the area. Taxes: $150, insurance: $100, water: $30, garbage: $30, sewer: $30, lawn care: $500.")
        print("\n")
        print("*******")
        sleep(2)
        print("Now some additional expenses that you should keep in mind that are more like emergency funds. You should account for saving some of your income in case there is a vacancy, for any repairs that are needed, and also capital expenditures.")
        print("\n")
        print("*******")
        sleep(2)
        print("For vacancy it is recommeded that you save 5 percent of your rental income. I can go ahead and automatically calculate that for you.")
        print("\n")
        print("*******")
        sleep(2)
        print("For repairs and capital expenditures you should save about $100 per month per unit. I can also calculate this for you and add it to your total costs.")
        print("\n")
        print("*******")
        sleep(2)
        print("The last two things you should think about are your mortgage cost and property management fees. Property management can vary but I would recommend saving $200 a month. Your mortgage is going to depend on how much money you put down.")
        print("\n")
        print(self.fees)
        self.cashflow()


    def cashflow(self):
        print("\n")
        sleep(1)
        print("Now that we have figured out your monthly income as well as monthly expenses we can see how much money you will earn each month. To figure that out we can subtract the total expenses from the total income.")
        total_expenses = sum(self.fees.values())
        total_income = sum(self.income.values())
        self.cash_flow += (total_income - total_expenses)
        final_cash_flow = round(self.cash_flow, 2)
        print(f"The total cash flow you will have each month based on all the expenses and the income you can earn is {final_cash_flow} a month.")
        self.cash_on_cash()

    def cash_on_cash(self):
        print("\n")
        sleep(1)
        print("The last factor we need to calculate is called cash on cash return on investment. To do this you can multiply your monthly cash flow by 12 to see how much is made anually. Then divide that by your total investment. Your total investment will include your down payment and closing costs. That will give you a percentage for your cash on cash ROI.")
        return_investment = (self.cash_flow * 12) / int((self.mortgage + 3000))
        flt_invest = round(return_investment, 2)
        sleep(1)
        print("\n")
        print(f"Your cash on cash return on investment is {flt_invest} percent.")
        if return_investment < 1:
            print("This may not be the smartest investment for you at this time :( ")
        elif return_investment > 1:
            print("Depending on your goals, savings, or if you have additional income this might be a good way to bring in some additional money... ")
        else:
            print("Get the mortgage now and start making money.")
        
        

class Calc:

    def run():
        my_calc = ROI()
        while True: 
            intro = input("Welcome to Bigger Pockets. Our goal is to help you calculate your ROI to see if this investment is something that would be worth it to you. To get started you can enter 'S' to start the process from the beginning or 'Q' to quit. ")
            if intro.lower() == 's':
                my_calc.cost()
            elif intro.lower() == "q":
                print("Guess you will never know... Bye")
                break 
            else:
                print("Invalid input, please try again.")

# %%
Calc.run()
# Out:
# Welcome to Bigger Pockets. Our goal is to help you calculate your ROI to see if this investment is something that would be worth it to you. To get started you can enter 'S' to start the process from the beginning or 'Q' to quit. S
# What is the cost of the home you are interested in purchasing ? 500000
# What percentage can you put down? 20
# How many units would you be able to rent out? 4
# If you choose to rent out the space, how much would you charge a month in total? 13000
#
#
# Great, now that you have an idea of how much you can charge for rent let's see some other ways you can make additional income.
# What sources of alternative income will you have? Charge for laundry, offer storage unit, a parking space, all of the above, or nothing else? all of the above
# The average person does about 6 loads of laundry a month. How much would you like to charge for using a washer AND dryer? 2
# A storage unit conveniently located in the building can go for about $50-$100/month. How much would you like to charge for storage? 100
# How much would you like to charge for parking? If it is a covered spot you can charge a bit more. 100
#
#
# Another thing you have to think about is all the additional expenses when purchasing property.
#
#
# *******
# The tenent should be responsible for gas, electric, and internet but the rest are generally covered by the owner. For now I will add the rest to your total cost based on the average for the area. Taxes: $150, insurance: $100, water: $30, garbage: $30, sewer: $30, lawn care: $500.
#
#
# *******
# Now some additional expenses that you should keep in mind that are more like emergency funds. You should account for saving some of your income in case there is a vacancy, for any repairs that are needed, and also capital expenditures.
#
#
# *******
# For vacancy it is recommeded that you save 5 percent of your rental income. I can go ahead and automatically calculate that for you.
#
#
# *******
# For repairs and capital expenditures you should save about $100 per month per unit. I can also calculate this for you and add it to your total costs.
#
#
# *******
# The last two things you should think about are your mortgage cost and property management fees. Property management can vary but I would recommend saving $200 a month. Your mortgage is going to depend on how much money you put down.
#
#
# {'taxes': 150, 'insurance': 100, 'water': 30, 'garbage': 30, 'sewer': 30, 'lawn care': 500, 'property management': 200, 'mortgage': 2147.29, 'capital expenditures': 400, 'repairs': 400, 'vacancy': 650.0}
#
#
# Now that we have figured out your monthly income as well as monthly expenses we can see how much money you will earn each month. To figure that out we can subtract the total expenses from the total income.
# The total cash flow you will have each month based on all the expenses and the income you can earn is 8610.71 a month.
#
#
# The last factor we need to calculate is called cash on cash return on investment. To do this you can multiply your monthly cash flow by 12 to see how much is made anually. Then divide that by your total investment. Your total investment will include your down payment and closing costs. That will give you a percentage for your cash on cash ROI.
#
#
# Your cash on cash return on investment is 1.0 percent.
# Depending on your goals, savings, or if you have additional income this might be a good way to bring in some additional money...
# Welcome to Bigger Pockets. Our goal is to help you calculate your ROI to see if this investment is something that would be worth it to you. To get started you can enter 'S' to start the process from the beginning or 'Q' to quit. q
# Guess you will never know... Bye
